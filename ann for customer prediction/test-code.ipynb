# %%
#test code

# %%
import numpy as np
import pandas as pd
from DPP_NEW import dataPreprocess

dataset_judge= pd.read_csv('judge.csv')

# %%
dataset_judge
# Out:
#      CustomerId          Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0      15605215        Stevenson          767    France    Male   48       9
# 1      15567855   Chukwufumnanya          623    France  Female   29       1
# 2      15780256       Palfreyman          630    France    Male   34       9
# 3      15592229           Mullan          713    France  Female   52       0
# 4      15788683             Kang          588   Germany  Female   34      10
# 5      15693203           Powell          710     Spain  Female   75       5
# 6      15635125          Findlay          566     Spain    Male   63       2
# 7      15582129             Hsia          517    France    Male   62       1
# 8      15703482           Walker          710   Germany    Male   34       9
# 9      15670738         Mazzanti          733   Germany    Male   45       2
# 10     15624775        Onyeoruru          729    France    Male   67       2
# ...

# %%
X=dataset_judge.iloc[:, 2:12].values

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_X1=LabelEncoder()
X[:,1]=labelencoder_X1.fit_transform(X[:,1])
labelencoder_X2=LabelEncoder()
X[:,2]=labelencoder_X2.fit_transform(X[:,2])

# %%
layer0 = X
layer1 = sigmoidActivation(np.dot(layer0, SynapseMatrix1))
layer2 = sigmoidActivation(np.dot(layer1, SynapseMatrix2))
layer3 = sigmoidActivation(np.dot(layer2, SynapseMatrix3))
layer4 = sigmoidActivation(np.dot(layer3, SynapseMatrix4))
y_pred = layer4

# %%
Exited=(y_pred>=0.5).astype(int) 
Exited=Exited.astype(int)

# %%
import csv
CustomerID=dataset_judge.iloc[:, 0].values
CustomerID= CustomerID.reshape((-1, 1))

# %%
B=np.vstack((CustomerID, Exited))
B=B.T

# %%
#generating the oupput judge-judge-pred.csv file

with open("jugde_pred.csv","w+") as my_csv:
    csvWriter = csv.writer(my_csv,delimiter=',')
    csvWriter.writerows(B)
